# %% [markdown]
# # IDEAI · Curso Auditoría de Modelos · Día 3 (Masterclass Plus)
#
# Este material amplía la sesión del Día 3 con tres mejoras clave:
#
# 1. **Dataset real de imágenes**
# 2. **Fine-tuning real con Hugging Face usando Trainer API**
# 3. **Caso práctico bancario end-to-end**
#
# La filosofía sigue siendo la misma:
# - teoría escrita y bien explicada,
# - código paso a paso,
# - bloques visibles,
# - ejercicios,
# - y orientación docente realista.

# %% [markdown]
# # Recapitulación y cierre del workshop
#
# ## 1. Qué hemos visto en el Día 3
#
# ### CNN
# - lógica de convolución
# - jerarquía de características
# - entrenamiento sobre imágenes reales
#
# ### Hugging Face
# - checkpoints preentrenados
# - tokenización
# - fine-tuning real con Trainer API
#
# ### Caso bancario end-to-end
# - integración de tabular, texto e imagen
# - combinación de scores
# - necesidad de gobernanza y auditoría

# %% [markdown]
# ## 2. Mensaje final del workshop
#
# El mensaje central del curso no es que el alumno memorice 20 algoritmos.
# Es entender que un sistema de modelización serio exige:
#
# - datos correctos,
# - preprocesado correcto,
# - evaluación rigurosa,
# - interpretación,
# - gobernanza,
# - y criterio de negocio.

# %% [markdown]
# ## 3. Ejercicio de cierre
#
# Imagina que eres responsable de validación interna en una entidad bancaria.
#
# Debes evaluar una propuesta que incluye:
# - un modelo tabular de impago,
# - un clasificador de emails de incidencia,
# - una CNN para validar documentación.
#
# ### Tarea
# Escribe un informe breve indicando:
# 1. beneficios del sistema,
# 2. riesgos,
# 3. requisitos mínimos para aprobar un piloto.

# %%
# Escribe aquí tu respuesta

# %% [markdown]
# ## 4. Solucionario orientativo
#
# Un buen cierre debería mencionar:
# - mejora del poder predictivo,
# - integración multimodal,
# - necesidad de documentación,
# - revisión de sesgos,
# - control de drift,
# - supervisión humana,
# - validación por bloques y del sistema completo.
